# %%
import pandas as pd


data = {
    'Name':   ['Alice', 'Bob', 'Alice', 'David', 'Bob'],
    'Age':    [25, 30, 25, 35, 30],
    'City':   ['Delhi', 'Mumbai', 'Delhi', 'Chennai', 'Mumbai']
}
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)


print("\nDuplicate Rows:")
print(df[df.duplicated()])

print("\nIs Duplicate (row-wise):")
print(df.duplicated())


df_cleaned = df.drop_duplicates()
print("\nAfter Removing Duplicates:")
print(df_cleaned)
# Out:
# Original DataFrame:
#     Name  Age     City
# 0  Alice   25    Delhi
# 1    Bob   30   Mumbai
# 2  Alice   25    Delhi
# 3  David   35  Chennai
# 4    Bob   30   Mumbai
#
# Duplicate Rows:
#     Name  Age    City
# 2  Alice   25   Delhi
# 4    Bob   30  Mumbai
#
# Is Duplicate (row-wise):
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool
#
# After Removing Duplicates:
#     Name  Age     City
# 0  Alice   25    Delhi
# 1    Bob   30   Mumbai
# 3  David   35  Chennai
