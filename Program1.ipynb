# %%
import pandas as pd
import numpy as np


data = {
    'Name':   ['Alice', 'Bob', None, 'David', 'Eve'],
    'Age':    [25, np.nan, 30, np.nan, 22],
    'Salary': [50000, 60000, np.nan, 45000, np.nan]
}
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

print("\nMissing Values:")
print(df.isnull())

print("\nMissing Value Count:")
print(df.isnull().sum())


df['Age'] = df['Age'].fillna(df['Age'].mean())


df['Salary'] = df['Salary'].fillna(df['Salary'].median())

print("\nAfter Replacing Missing Values:")
print(df)

df_dropped = df.dropna()
print("\nAfter Dropping Rows with Missing Values:")
print(df_dropped)
# Out:
# Original DataFrame:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# 1    Bob   NaN  60000.0
# 2   None  30.0      NaN
# 3  David   NaN  45000.0
# 4    Eve  22.0      NaN
#
# Missing Values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False   True   False
# 4  False  False    True
#
# Missing Value Count:
# Name      1
# Age       2
# Salary    2
# dtype: int64
#
# After Replacing Missing Values:
#     Name        Age   Salary
# 0  Alice  25.000000  50000.0
# 1    Bob  25.666667  60000.0
# 2   None  30.000000  50000.0
# 3  David  25.666667  45000.0
# 4    Eve  22.000000  50000.0
#
# After Dropping Rows with Missing Values:
#     Name        Age   Salary
# 0  Alice  25.000000  50000.0
# 1    Bob  25.666667  60000.0
# 3  David  25.666667  45000.0
# 4    Eve  22.000000  50000.0
